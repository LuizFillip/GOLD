# %%
import cartopy.crs as ccrs
import cartopy.feature as cf
import pandas as pd 
import numpy as np 
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import datetime

from split_filename import *
from GOLD import *


infile = 'C:\\Users\\Luiz Felipe\\Downloads\\TLIMB2019111120191112\\tmp\\archive_L2\\2019\\315\\'

filename = 'GOLD_L2_TLIMB_2019_315_v03_r01_c01.nc'

ds = xr.open_dataset(infile + filename)

ds.coords['nscans'] = bytes_string(ds['scan_start_time'])




sel.mean(dim = 'nlats', skip )
# Out:
# C:\Users\Luiz Felipe\anaconda3\lib\site-packages\xarray\core\nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# <xarray.Dataset>
# Dimensions:                           (nlons: 30, nmask: 4001, nscans: 25)
# Coordinates:
#   * nscans                            (nscans) object 2019-11-11T07:04:14+00:00 ... 2019-11-11T23:04:14+00:00
# Dimensions without coordinates: nlons, nmask
# Data variables:
#     tlimb_unc_mod                     (nscans) float32 nan nan nan ... nan nan
#     n2_lbh_unc_ran                    (nscans, nlons) float64 77.47 ... 14.91
#     n2_scale_height_unc_ran           (nscans) float32 0.5595331 ... 0.59553605
#     tlimb                             (nscans) float32 748.3309 ... 815.1458
#     mask_wavelength                   (nmask) float32 130.0 130.01 ... 170.0
#     tlimb_dqi                         (nscans) float64 23.25 23.25 ... 21.5 29.5
# ...

# %%
sel = ds.isel(nscans = np.arange(0, len(ds.nscans), 2))

fig, ax = plt.subplots(figsize = (10, 4))

for i in range(len(ds.nlats) - 1):
    sel['tlimb'].isel(nlats = i).plot(lw = 0.5, color = 'red')

sel['tlimb'].mean(dim = 'nlats').plot(lw = 2, color = 'black')

# %%
lats = sel['tangent_point_latitude']

lons = sel['tangent_point_longitude']

alts = sel['tangent_point_altitude']

data = sel['radiance_n2_lbh']


fig, ax = plt.subplots(figsize = (10, 4))

for hemisphere in range(2):
    sel = ds.isel(nscans = np.arange(hemisphere, len(ds.nscans), 2))
    alts = sel['tangent_point_altitude']
    alts.mean(dim = ['nlats', 'nlons'], skipna = True).plot()

# %%
time = ds.nscans.values
ds.sel(nscans = time[0])

import pytz
utc=pytz.UTC



start1 = datetime.datetime(2019, 11, 11, 7).replace(tzinfo=utc)
end1 = datetime.datetime(2019, 11, 11, 14).replace(tzinfo=utc)


start2 = datetime.datetime(2019, 11, 11, 16).replace(tzinfo=utc)
end2 = datetime.datetime(2019, 11, 11, 19).replace(tzinfo=utc)


start3 = datetime.datetime(2019, 11, 11, 19).replace(tzinfo=utc)
end3 = datetime.datetime(2019, 11, 11, 22).replace(tzinfo=utc)


period_1 = []
period_2 = []
period_3 = []

for item in time:
    if (start1 > item) or (item < end1):
        
        period_1.append(item)
    elif (start2 > item) or (item < end2):
        
        period_2.append(item)
    else:
        period_3.append(item)
# Out:
# False

# %%
sel = ds.sel(nscans = period_1)

sel = sel.isel(nscans = np.arange(1, len(sel.nscans), 2))

lats = sel['tangent_point_latitude'].values

lons = sel['tangent_point_longitude'].values

data = sel['radiance_n2_lbh'].values

sel['tangent_point_longitude'].isel(nscans = 1).plot()
