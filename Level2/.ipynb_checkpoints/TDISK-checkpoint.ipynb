# %%
import pandas as pd 
import numpy as np 
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import datetime
import cartopy.feature as cf
import cartopy.crs as ccrs

from split_filename import *
from GOLD import *
import os

# %%
infile = 'C:\\Users\\Luiz Felipe\\Downloads\\TDISK2019111120191112\\tmp\\archive_L2\\2019\\315\\' 
filename = 'GOLD_L2_TDISK_2019_315_v02_r01_c01.nc'



def sep_hemispheres(ds, parameter = 'n2_lbh_unc_ran'):
    
    """
    returns
    -------
        like dataframe with informations of south and north
    """

    south = ds.isel(nscans = np.arange(1, len(ds.nscans.values), 2))

    df_south = south[parameter].mean(dim = ['nlats', 'nlons'],  skipna = True).to_dataframe()
    
    north = ds.isel(nscans = np.arange(0, len(ds.nscans.values), 2))
    
    df_north = north[parameter].mean(dim = ['nlats', 'nlons'],  skipna = True).to_dataframe()
    
    df_south.index.name = 'Time UTC'
    df_south.columns = ['south']
    df_north.index.name =  'Time UTC'
    df_north.columns = ['north']

    return df_north, df_south

def plotting_hemispheres(ax, ds, parameter = 'radiance_oi_1356'):
    
    north, south = sep_hemispheres(ds, parameter = parameter)
    
    north.plot(ax = ax, color = 'red', lw = 2, legend = False)
    south.plot(ax = ax, color = 'black', lw = 2, legend = False)

    args_names = ds[parameter].attrs
    title = args_names['FIELDNAM']
    xlabel = 'Time UTC'
    name = args_names['CATDESC']
    units = args_names['UNITS']
    #ylabel = args_names['LABLAXIS']

    ax.set(xlabel = xlabel, ylabel = f"{name} ({units})")

    ax.xaxis.set_major_formatter(dates.DateFormatter('%H:%M'))
    ax.xaxis.set_major_locator(dates.HourLocator(interval = 2))

# %%
ds = xr.open_dataset(infile + filename)

ds.coords['nmask'] = ds['mask_wavelength']
ds.coords['nscans'] = bytes_string(ds['scan_start_time'])

ds
# Out:
# <xarray.Dataset>
# Dimensions:                  (nlats: 104, nlons: 92, nmask: 4001, npop: 7, nscans: 68)
# Coordinates:
#   * nmask                    (nmask) float32 130.0 130.01 ... 169.98999 170.0
#   * nscans                   (nscans) object 2019-11-11T06:10:34+00:00 ... 2019-11-11T22:52:23+00:00
# Dimensions without coordinates: nlats, nlons, npop
# Data variables:
#     mask_wavelength          (nmask) float32 ...
#     effective_altitude       (nscans, nlats, nlons) float32 ...
#     lookup_table             (nscans) |S50 ...
#     tdisk_unc_ran            (nscans, nlats, nlons) float32 ...
#     wavelength_stretch       (nscans, nlats, nlons) float32 ...
#     channel                  (nscans) |S50 ...
#     latitude                 (nlats, nlons) float32 ...
#     dqi                      (nscans) int32 ...
#     scan_start_time          (nscans) |S50 b'2019-11-11T06:10:34Z' ... b'2019-11-11T22:52:23Z'
#     solar_zenith_angle       (nscans, nlats, nlons) float32 ...
#     tdisk_unc_sys            (nscans, nlats, nlons) float32 ...
#     tdisk                    (nscans, nlats, nlons) float32 ...
#     time_utc                 (nscans, nlats, nlons) |S50 ...
#     background               (nscans, nlats, nlons) float32 ...
#     wavelength_shift         (nscans, nlats, nlons) float32 ...
#     longitude                (nlats, nlons) float32 ...
#     vibrational_populations  (nscans, nlats, nlons, npop) float32 ...
#     input_l1c_file           (nscans) |S50 ...
#     emission_angle           (nscans, nlats, nlons) float32 ...
#     tdisk_dqi                (nscans, nlats, nlons) int32 ...
#     mask_n2_lbh              (nmask) int32 ...
#     scan_stop_time           (nscans) |S50 ...
#     tdisk_unc_mod            (nscans, nlats, nlons) float32 ...
#     hemisphere               (nscans) |S50 ...
# Attributes:
#     Data_revision:               01
#     Logical_source:              GOLD_L2_TDISK
#     PI_name:                     Richard Eastes
#     TEXT:                        The GOLD mission of opportunity flies an ult...
#     Mission_group:               GOLD
#     Data_version:                02
#     Data_type:                   APIDx? > GOLD Application ID 0x?: Level 2 Da...
#     Generation_date:             20191111
#     date_start:                  2019-11-11T06:10:34Z
#     dqi:                         0
#     Instrument_type:             UV Imaging Spectrograph (Space)
#     PI_affiliation:              University of Colorado/LASP
#     Source_name:                 GOLD>Global-scale Observations of the Limb a...
#     Data_cycle:                  01
#     Acknowledgement:             This is a data product from the NASA Global-...
#     Logical_source_description:  GOLD TDISK L2 Daily File
#     Discipline:                  Space Physics > Ionospheric Science
#     Logical_file_id:             GOLD_L2_TDISK_2019_315_v02_r01_c01
#     date_end:                    2019-11-11T23:03:46Z
#     Descriptor:                  TDISK>Disk neutral temperature
#     Project:                     NASA > GOLD
#     Software_version:            dafdbd1

# %%
n = ds.isel(nscans = np.arange(0, len(ds.nscans), 2))
s = ds.isel(nscans = np.arange(1, len(ds.nscans), 2))

combine_sets = [] 
for i in range(len(n.nscans)):
    datasets = n.isel(nscans = i).combine_first(s.isel(nscans = i))
    combine_sets.append(datasets)

# %%
dslist = combine_sets[::4]
ds1 = dslist[4]

quality = ds1['tdisk_dqi'].values
data = ds1[parameter].values

data[quality != 0] = np.nan

plt.imshow(data)

# %%
fig, ax = plt.subplots(figsize = (12, 12), ncols = 3, nrows = 3, 
                       subplot_kw={'projection': ccrs.Orthographic(central_longitude= - 47.5)})


plt.subplots_adjust(wspace = 0.1, hspace = 0.1)


name = ds1[parameter].attrs['CATDESC']
units = ds1[parameter].attrs['UNITS']

for ax, num in zip(ax.flat, range(len(dslist))):
    
    features_of_map(ax)
    
    time =  bytes_string(dslist[num]['scan_start_time'])
    time = str(time.values)[11:-9]
    
    ax.set(title = f'{time} UTC')
    
    ds1 = dslist[num]

    data = ds1[parameter].values
    lons = ds1['longitude'].values
    lats = ds1['latitude'].values

    img = ax.contourf(lons, lats, data, 50, cmap = 'seismic', 
                              transform = ccrs.PlateCarree())
     
    cbar_ax = fig.add_axes([.09, 0.2, 0.02, 0.6])

    cs = fig.colorbar(img, cax=cbar_ax, ticklocation='left')

    cs.set_label(f"{name} ({units})")
    
    
        
fig.suptitle('GOLD \n' + split_filename(filename).date(), y = .95)

plt.show()
# Out:
# C:\Users\Luiz Felipe\anaconda3\lib\site-packages\ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
def figure_name(files, emission):
    
    emission = emission.replace(' ', '_')
    
    if isinstance(files, list):
        
        if len(files) == 2:
            first, second = files[0], files[1]
        else:
            first, second = files[0], files[-1]
            
        start = split_filename(first)
        end = split_filename(second)
        time_start, time_end = start.time().replace(':',''), end.time().replace(':','')
        date = str(start.date(extent = False)).replace('-', '_')
        
        return f"GOLD_{start.product}_{emission}_{date}_{time_start}_{time_end}"
    else:
        start = split_filename(filename)
        if start.level == 'L2':
             return f"GOLD_{emission.upper()}_{start.level}_{str(start.date(extent = False)).replace('-', '_')}"
        

FigureName = figure_name(filename, 'tdisk_unc')

FigureName
# Out:
# 'GOLD_TDISK_UNC_L2_2019_11_11'

# %%
fig, ax = plt.subplots(figsize = (14, 5), ncols = 2)


parameters_list = ['tdisk', 'tdisk_unc_ran']

for ax, parameter in zip(ax.flat, parameters_list):
    
    plotting_hemispheres(ax, ds, parameter = parameter)

    ax.legend(['north', 'south'])

fig.autofmt_xdate(rotation=0, ha = 'center')

args_file = split_filename(filename)

fig.suptitle(args_file.date())

plt.show()

# %%
PathOut = 'C:\\Users\\Luiz Felipe\\Google Drive\\Doutorado\\Modelos_Latex_INPE\\Figuras1\\'

fig.savefig(PathOut + FigureName + '.png', dpi = 100, quality = 95, bbox_inches="tight")
