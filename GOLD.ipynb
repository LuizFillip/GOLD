# %%
import datetime

yr_start = 2019
yr_end = 2019


for doy in [290, 365]:
    _date = datetime.date(yr_end, 1, 1) + datetime.timedelta(doy - 1)
    print(_date)
# Out:
# 2019-10-17
# 2019-12-31

# %%
ds['temperature'].plot()

# %%
fig, ax = plt.subplots(figsize = (10, 4), ncols = 2)
ax[0].imshow(ds['longitude'].values)

ax[1].imshow(ds['latitude'].values)

# %%
ds['mask_oi_1356'].plot()

# %%
for i in range(22, 30):
    fig, ax = plt.subplots()
    ds['on2'][i].plot()
# Out:
# Error in callback <function flush_figures at 0x0000025B1CA2C3A8> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ...

# %%
for i in range(30, 40):
    fig, ax = plt.subplots()
    ds['on2_unc_mod'][i].plot(ax = ax)

# %%
ds['time_utc'][0].values
# Out:
# array([[b'************************', b'************************',
#         b'************************', ..., b'************************',
#         b'************************', b'************************'],
#        [b'************************', b'************************',
#         b'************************', ..., b'************************',
#         b'************************', b'************************'],
#        [b'************************', b'************************',
#         b'************************', ..., b'************************',
#         b'************************', b'************************'],
#        ...,
#        [b'************************', b'************************',
#         b'************************', ..., b'************************',
#         b'************************', b'************************'],
#        [b'************************', b'************************',
#         b'************************', ..., b'************************',
# ...

# %%
for i in range(2, 10):
    fig, ax = plt.subplots()
    ds['radiance_n2_lbh'][i].plot()

# %%
for i in range(5, 12):
    fig, ax = plt.subplots()
    ds['oi_1356_unc_sys'][i].plot()

# %%
file = 'GOLD_L2_TDISK_2020_316_v02_r01_c02.nc'

ds = xr.open_dataset(file)

ds
# Out:
# <xarray.Dataset>
# Dimensions:                  (nlats: 104, nlons: 92, nmask: 4001, npop: 7, nscans: 68)
# Dimensions without coordinates: nlats, nlons, nmask, npop, nscans
# Data variables:
#     mask_wavelength          (nmask) float32 ...
#     effective_altitude       (nscans, nlats, nlons) float32 ...
#     lookup_table             (nscans) |S50 ...
#     tdisk_unc_ran            (nscans, nlats, nlons) float32 ...
#     wavelength_stretch       (nscans, nlats, nlons) float32 ...
#     channel                  (nscans) |S50 ...
#     latitude                 (nlats, nlons) float32 ...
#     dqi                      (nscans) int32 ...
#     scan_start_time          (nscans) |S50 ...
#     solar_zenith_angle       (nscans, nlats, nlons) float32 ...
#     tdisk_unc_sys            (nscans, nlats, nlons) float32 ...
#     tdisk                    (nscans, nlats, nlons) float32 ...
#     time_utc                 (nscans, nlats, nlons) |S50 ...
# ...

# %%
for i in range(20, 29): 
    fig, ax = plt.subplots()
    ds['tdisk_unc_ran'][i].plot()

# %%
ds['effective_altitude'].plot()
# Out:
# (array([     0.,      0.,      0.,      0.,      0., 130357.,      0.,
#              0.,      0.,      0.]),
#  array([149.5, 149.6, 149.7, 149.8, 149.9, 150. , 150.1, 150.2, 150.3,
#         150.4, 150.5], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
for i in range(20, 29): 
    fig, ax = plt.subplots()
    ds['wavelength_stretch'][i].plot()
